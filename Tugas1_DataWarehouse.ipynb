# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

# %%
iris = pd.read_csv('iris.csv')

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.head()
# Out:
#    asus  lenovo  acer    hp species
# 0   3.0    10.0  13.0  15.0  laptop
# 1  13.0     5.0  12.0  15.0  laptop
# 2   2.0    14.0  12.0  10.0  laptop
# 3  11.0     4.0   5.0   2.0  laptop
# 4   5.0     6.0   8.0   3.0  laptop

# %%
iris.plot(x='asus', y='lenovo')
# Out:
# <AxesSubplot:xlabel='asus'>
